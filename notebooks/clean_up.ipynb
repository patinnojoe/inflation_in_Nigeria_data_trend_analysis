# %%
from pathlib import Path
import sys

PROJECT_ROOT = Path().resolve().parents[0]
if str(PROJECT_ROOT) not in sys.path:
    sys.path.append(str(PROJECT_ROOT))
    
import pandas as pd
from src.config import RAW_DATA_DIR
from src.config import PROCESSED_DATA_DIR
from src.utils.wrangle import wrangle


df = wrangle(RAW_DATA_DIR / 'nigeria_monthly_cpi_2019_2025.csv')
# save the processed file
df.to_csv(PROCESSED_DATA_DIR / "inflation_in_nigeria_2019_2025_clean.csv")

df.head()
# Out:
#             overall_cpi  core_cpi_ex_food  core_cpi_ex_food_energy  \
# date
# 2019-01-01        37.22             44.32                    43.65
# 2019-02-01        37.49             44.61                    43.95
# 2019-03-01        37.79             44.85                    44.20
# 2019-04-01        38.14             45.16                    44.50
# 2019-05-01        38.57             45.50                    44.86
#
#             imported_food_cpi  food_cpi  food_non_alcoholic_beverages_cpi  \
# date
# 2019-01-01              36.39     32.05                             32.20
# 2019-02-01              36.84     32.32                             32.47
# 2019-03-01              37.28     32.60                             32.75
# 2019-04-01              37.75     32.97                             33.12
# 2019-05-01              38.22     33.43                             33.58
#
#             alcohol_tobacco_drugs_cpi  clothing_footwear_cpi  \
# date
# 2019-01-01                      46.40                  47.90
# 2019-02-01                      46.76                  48.23
# 2019-03-01                      47.12                  48.58
# 2019-04-01                      47.50                  48.95
# 2019-05-01                      47.90                  49.35
#
#             utilities_housing_energy_cpi  household_goods_cpi  health_cpi  \
# date
# 2019-01-01                         46.63                48.63       43.44
# 2019-02-01                         46.87                48.96       43.72
# 2019-03-01                         47.17                49.30       44.05
# 2019-04-01                         47.50                49.65       44.40
# 2019-05-01                         47.84                50.03       44.75
#
#             transport_cpi  communication_cpi  recreation_culture_cpi  \
# date
# 2019-01-01          41.45              64.60                   56.11
# 2019-02-01          41.74              64.98                   56.45
# 2019-03-01          42.02              65.38                   56.80
# 2019-04-01          42.32              65.79                   57.17
# 2019-05-01          42.63              66.22                   57.56
#
#             education_cpi  restaurants_accommodation_cpi  \
# date
# 2019-01-01          48.33                          44.49
# 2019-02-01          48.67                          44.78
# 2019-03-01          48.99                          45.06
# 2019-04-01          49.32                          45.33
# 2019-05-01          49.67                          45.63
#
#             personal_care_misc_cpi  mom_inflation_pct  yoy_inflation_pct  \
# date
# 2019-01-01                   45.49               0.74              11.37
# 2019-02-01                   45.80               0.73              11.31
# 2019-03-01                   46.09               0.79              11.25
# 2019-04-01                   46.39               0.94              11.37
# 2019-05-01                   46.74               1.11              11.40
#
#             avg_12m_inflation_pct
# date
# 2019-01-01                  11.80
# 2019-02-01                  11.56
# 2019-03-01                  11.40
# 2019-04-01                  11.31
# 2019-05-01                  11.30
